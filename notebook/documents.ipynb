# %% [markdown]
# ## Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Eyasu Berhane Habte",
        "date_created":"2025-10-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Eyasu Berhane Habte', 'date_created': '2025-10-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
from langchain_community.document_loaders import DirectoryLoader, PyMuPDFLoader

# Load all PDFs from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",  # Pattern to match all PDFs recursively
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()
print(f"Loaded {len(pdf_documents)} documents.")

# Preview first document
if pdf_documents:
    print(pdf_documents[0].page_content[:500])  # first 500 characters
    print(pdf_documents[0].metadata)
# Out:
# Loaded 346 documents.
# 2021
# PARTNERING IN GROWTH
# ESG AND
# CLIMATE CHANGE
# REPORT
# {'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 15.1 (Macintosh)', 'creationdate': '2021-09-03T13:56:41+02:00', 'source': '..\\data\\pdf\\2021ESG.pdf', 'file_path': '..\\data\\pdf\\2021ESG.pdf', 'total_pages': 116, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2021-09-03T14:02:34+02:00', 'trapped': '', 'modDate': "D:20210903140234+02'00'", 'creationDate': "D:20210903135641+02'00'", 'page': 0}
